# %%
file = "./readcounts_BM.tsv"

# %%
counts = {}

with open(file) as f:
    for line in f:
        if line[0] == "\t":
            continue
        counts[line.split()[0]] = line.strip().split()

# %%
with open("readcounts_BM_long.csv", 'w') as f:
    f.write("gene,species,replicate,exprval\n")
    for i in range(1, 101):
        for cell, value in counts.items():
            f.write(f"{i},{cell},R1,{value[i]}\n")

# %%
file = "./readcounts_OU.tsv"

# %%
counts = {}

with open(file) as f:
    for line in f:
        if line[0] == "\t":
            continue
        counts[line.split()[0]] = line.strip().split()

# %%
with open("readcounts_OU_long.csv", 'w') as f:
    f.write("gene,species,replicate,exprval\n")
    for i in range(1, 101):
        for cell, value in counts.items():
            f.write(f"{i},{cell},R1,{value[i]}\n")
